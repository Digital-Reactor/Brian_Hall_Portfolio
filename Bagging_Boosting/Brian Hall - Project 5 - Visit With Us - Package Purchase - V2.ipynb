# %% [markdown]
# ## Visit With Us
# ## Travel Package PUrchase Prediction
# #### Brian Hall
# #### DSBA - Project 5
# #### 07/16/2021
# ### Problem
# Visit With Us is working to expand their customer base by creating a new product offerings called the Wellness Tourism Package.  Currently there are 5 types of packages the company is offering and a marketing campaign from the previous year showed an 18% customer purchase rate, however the costs for the campaign were high.  Visit With Us would like to utilize the data from the previous marketing campaign to predict which customers will potentially purchase the newly introduced travel package.
# ### Objective
# Utilizing data obtained from the previous successful campaign we will create customer profiles for each product & build machine learning models with the potential to predict what types of customers Marketing could be targeted in a new campaign.
# ### Recommendations
# **Utilize the new Customer Profiles by Product and the individuals predicted within each to create new marketing guidelines for outreach and products to pitch.  This would allow better interaction and increased purchase rates with existing customers, while potentially reducing the number of follow ups and duration of pitch.  This would also allow for the ability to better market individual packages to appropriate audiences and increase success of outreach for higher profit tourism packages.**
#
# - Without additional information on the Wellness Tourism Package, such as expense / benefits, it is difficult to determine which customers may opt for that package.  Once the new package is classified along with the Customer Profiles by Product it should be easier to predict who will purchase each product.
#
#
# - Additional data on customers lifestyles could help improve / create models to predict who will opt for the new Wellness Tourism Package.
#
#
# - Additional research on what type of individual is more likely to be interested in wellness and travel would also be advised.  Possibly introduce a 'Wellness Score' to existing data and rework profiles / re-train the models.
#
#
# - Monthly Income, Age & Duration of Pitch are showing as the most important features for the model in predicting who will purchase a product, EDA mostly agrees with this.
#
#
# - Product Pitched is also showing as an important feature and EDA supports this, however the Product Pitched maps perfectly to Designation and has some correlation with Income & Age.  Using Designation as the sole means of determining what product to pitch to a given customer is not likely a good practice as many other factors, outside the scope of this data, could impact someones designation.  A better practice could be to determine which product to pitch based on the newly developed Customer Profiles by Product.  This may also reduce the slight negative correlation that ProductPitched has with ProdTaken.
#
#
# - Unmarried customers account for ~ 13% of observations and prefer the mid to lower priced products, it would be good to better understand who makes up this group.
#
#
# - Determine why the Standard package is not pitched more often as it has a higher purchase rate than the Deluxe package which is pitched more than 2x as often.
#
#
# - Self Enquiry has a 17% product purchase rate, only 4% lower than company invited, but accounts for 70% of observations. Determine if the cost of outreach is worth the additional 4% purchase rate and if putting those dollars to better targeted  marketing (predicted purchasers) would make more sense.
#
#
# - Increase marketing of Standard and Deluxe packages to single customers.
#
#
# - Reworking the data & data dictionary to better indicate if NumberOfPersonsVisiting include the customer or is in addition.  No customers are showing to travel alone, which makes this suspect.
#
#
# - Collecting additional data on products pitched once new guidelines for how products are pitched are in place will likely increase the predictive power of these models.
#
#
# - Including additional data such as family size, reason for trip, destination (in country, out of country, distance from home), better details on what drives the satisfaction score, how purchases are made (online, etc), what drove a Self Enquiry, etc. could greatly increase the outcomes of future analysis and marketing plans.

# %% [markdown]
# ## Data
# Data has been provided via Excel file (Tourism.xlsx  |  456k)
#
# The data is assumed to be a random subset of customers targeted during a previous marketing campaign.
#
#
# **Data Dictionary**
#
# Customer details:
#
# - CustomerID: Unique customer ID
# - ProdTaken: Whether the customer has purchased a package or not (0: No, 1: Yes)
# - Age: Age of customer
# - TypeofContact: How customer was contacted (Company Invited or Self Inquiry)
# - CityTier: City tier depends on the development of a city, population, facilities, and living standards. The categories are ordered i.e. Tier 1 > Tier 2 > Tier 3
# - Occupation: Occupation of customer
# - Gender: Gender of customer
# - NumberOfPersonVisiting: Total number of persons planning to take the trip with the customer
# - PreferredPropertyStar: Preferred hotel property rating by customer
# - MaritalStatus: Marital status of customer
# - NumberOfTrips: Average number of trips in a year by customer
# - Passport: The customer has a passport or not (0: No, 1: Yes)
# - OwnCar: Whether the customers own a car or not (0: No, 1: Yes)
# - NumberOfChildrenVisiting: Total number of children with age less than 5 planning to take the trip with the customer
# - Designation: Designation of the customer in the current organization
# - MonthlyIncome: Gross monthly income of the customer
#
# Customer interaction data:
#
# - PitchSatisfactionScore: Sales pitch satisfaction score
# - ProductPitched: Product pitched by the salesperson
# - NumberOfFollowups: Total number of follow-ups has been done by the salesperson after the sales pitch
# - DurationOfPitch: Duration of the pitch by a salesperson to the customer
#
# It is assumed that CityTier refers to the city that the customer resides in
#
# Note: ProductPitched mapps perfectly to Designation, it is unclear if this is a collection error or simply existing marketing guidelines

# %% [markdown]
# ## Model Observations
#
# - We have chosen the **Random Forest Tuned Weighted** model to move forward with, while it has an ~ 6% lower Test F1 score than the highest performer, the model is more generalized and likely to perform better when additional data is introduced.
#
# **Test F1 Score (0.720)**
#
# **Train F1 Score (0.923)**
#
# - The XGBoost Tuned model performed the best on Test F1 Score (0.785) but is overfitting on the training data F1 score (0.992)
# - Nearly every model is overfitting on the training data.
# - Models that are not overfitting have a poor F1 Test Score
#
#
# #### All models were trained with F1 Score as the metric

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Customer Profiles by Product
#
# #### Basic
# - Age: Pitched to all with a concentration < 25
# - MonthlyIncome: Concentration of pitches between 17k & 23k
# - MaritalStatus: Most popular with Single
# - CityTier: Most popular in Tier 3 cities
# - Gender, NumberOfPersonVisiting, NumberOfChildrenVisiting, Occupation, OwnCar & Passport are farily equal in distribution
#
# #### Standard
# - Age: Pitched to all > 27 with a concentration between 20 & 50
# - MonthlyIncome: Concentration of pitches between 23k & 30k
# - MaritalStatus: Most popular with Unmarried
# - CityTier: Most popular in Tier 1 cities
# - Gender, NumberOfPersonVisiting, NumberOfChildrenVisiting, Occupation, OwnCar & Passport are farily equal in distribution
#
# #### Deluxe
# - Age: Pitched to all with a concentration between 25 & 42
# - MonthlyIncome: Concentration of pitches between 18k & 26k
# - MaritalStatus: Most popular with Divorced & Married
# - CityTier: Most popular in Tier 1 cities
# - Gender, NumberOfPersonVisiting, NumberOfChildrenVisiting, Occupation, OwnCar & Passport are farily equal in distribution
#
# #### Super Deluxe
# - Age: Pitched to customer > 39 with a concentration between 42 & 55
# - MonthlyIncome: Concentration of pitches between 30k & 36K
# - MaritalStatus: Most popular with Single, Divorced & Married
# - CityTier: Most popular in Tier 1 cities
# - Gender, NumberOfPersonVisiting, NumberOfChildrenVisiting, Occupation, OwnCar & Passport are farily equal in distribution
#
# #### King
# - Age: Pitched to customer > 40 with a concentration between 42 & 55
# - MonthlyIncome: Concentration of pitches between 33k & 38k
# - MaritalStatus: Most popular with Single, Divorced & Married
# - CityTier: Most popular in Tier 3 cities
# - Gender, NumberOfPersonVisiting, NumberOfChildrenVisiting, Occupation, OwnCar & Passport are farily equal in distribution

# %% [markdown]
# #### ------------------------------------------------------------------------------------------------------------------------------------------------------------
# #### ------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Import Libraries and Global Options

# %%
# Library to suppress warnings or deprecation notes 
import warnings
warnings.filterwarnings('ignore')

# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Libraries to split data, impute missing values 
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# Libraries to import decision tree classifier and different ensemble classifiers
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.tree import DecisionTreeClassifier

# Libtune to tune model, get different metric scores
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import GridSearchCV

# Removes the limit from the number of displayed columns and rows.
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_rows', 200)

# %% [markdown]
# ### Retrieve, Examine and Prepare Data

# %%
#Read in data and sample
VWUMain = pd.read_excel("Tourism.xlsx",sheet_name='Tourism')
vwu = VWUMain.copy()
print(f'There are {vwu.shape[0]} rows and {vwu.shape[1]} columns.')  

np.random.seed(2021)
vwu.sample(n=10)
# Out:
# There are 4888 rows and 20 columns.
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 3744      203744          0  35.0     Self Enquiry         3             15.0
# 4701      204701          0  56.0  Company Invited         1              9.0
# 2427      202427          1   NaN     Self Enquiry         3             22.0
# 2502      202502          0  32.0     Self Enquiry         1             14.0
# 4387      204387          0  50.0     Self Enquiry         1             25.0
# 1557      201557          0  51.0     Self Enquiry         1             15.0
# 3406      203406          0  52.0     Self Enquiry         2             12.0
# 2155      202155          0  26.0  Company Invited         3              NaN
# 3170      203170          0  32.0  Company Invited         1              7.0
# 2530      202530          0  24.0     Self Enquiry         3              9.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# ...

# %% [markdown]
# #### Check Data Types & Missing Values / Duplicate Rows

# %%
#Examine data
vwu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
# -- Check for missing data
def findNulls(df):
    numOfNulls = df.isnull().sum().sort_values(ascending=False)
    percentOfNulls = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missingData = pd.concat([numOfNulls, percentOfNulls], axis=1, keys=['numOfNulls', 'percentOfNulls'])
    return missingData
print(findNulls(vwu))

# -- Check for duplicate rows
print('')
print('Before Duplicate Check', vwu.shape)
vwuObj = vwu
duplicateldfRow = vwuObj[vwuObj.duplicated()]
print('Duplicated Rows: ', len(duplicateldfRow))
print('')
print(duplicateldfRow)


print('')
print('After Duplicate Check', vwu.shape)
# Out:
#                           numOfNulls  percentOfNulls
# DurationOfPitch                  251        0.051350
# MonthlyIncome                    233        0.047668
# Age                              226        0.046236
# NumberOfTrips                    140        0.028642
# NumberOfChildrenVisiting          66        0.013502
# NumberOfFollowups                 45        0.009206
# PreferredPropertyStar             26        0.005319
# TypeofContact                     25        0.005115
# Passport                           0        0.000000
# MaritalStatus                      0        0.000000
# ProductPitched                     0        0.000000
# Designation                        0        0.000000
# NumberOfPersonVisiting             0        0.000000
# Gender                             0        0.000000
# Occupation                         0        0.000000
# PitchSatisfactionScore             0        0.000000
# CityTier                           0        0.000000
# ...

# %% [markdown]
# - 4888 Observations
# - 20 Variables
# - There are 8 variables with missing values
# - 15 variables require data type changes
# -- 8 to category
# -- 7 to integer
# - CustomerID should be dropped prior to modeling
# - Designation should be changed to int & ranked

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# #### Convert to categorical
# ProdTaken, TypeofContract, Occupation, Gender, MaritalStatus, Passport, OwnCar, ProductPitched
# #### Convert to integer after imputing missing values or binning
# Age, PreferredPropertyStar, NumberOfTrips, NumberOfChildrenVisiting, MonthlyIncome, NumberOfFollowups, DurationofPitch, Designation

# %%
# Convert identified variables to categorical
vwu = vwu.astype({"ProdTaken":'category', "Occupation":'category', "Gender":'category',
                  "MaritalStatus":'category', "Passport":'category', "OwnCar":'category', 
                  "ProductPitched":'category', "TypeofContact":'category', "Designation" : 'category',
                  })
vwu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   category
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   category
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   category
#  7   Gender                    4888 non-null   category
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   category
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   category
# ...

# %%
#Dropping CustomerID from the data set
vwu.drop(columns=['CustomerID'], inplace=True)

# %% [markdown]
# #### Summary of  variables

# %%
vwu.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       4662.0     37.622265     9.316387    18.0     31.0
# CityTier                  4888.0      1.654255     0.916583     1.0      1.0
# DurationOfPitch           4637.0     15.490835     8.519643     5.0      9.0
# NumberOfPersonVisiting    4888.0      2.905074     0.724891     1.0      2.0
# NumberOfFollowups         4843.0      3.708445     1.002509     1.0      3.0
# PreferredPropertyStar     4862.0      3.581037     0.798009     3.0      3.0
# NumberOfTrips             4748.0      3.236521     1.849019     1.0      2.0
# PitchSatisfactionScore    4888.0      3.078151     1.365792     1.0      2.0
# NumberOfChildrenVisiting  4822.0      1.187267     0.857861     0.0      1.0
# MonthlyIncome             4655.0  23619.853491  5380.698361  1000.0  20346.0
#
#                               50%      75%      max
# Age                          36.0     44.0     61.0
# ...

# %% [markdown]
# - Age mean and median are apx 36 (use median to impute missing values)
# - DurationOfPitch has a mean of apx 15 and median of 13 (check against other variables, missing values could correlate to ProdTaken or TypeOfContact.  Impute either as median (due to outliers) or -1 if missing values correlated to to other variables.  )
# -- there appear to be outliers as high of 127 investigate further
# - NumberOfPersonVisiting has a mean and median of apx 3
# - NumberOfFollowups has a mean and median apx 4 (use -1 to impute missing values)
# - PreferredPropertyStar has a mean of 3.58 and a median of 3 (use -1 to impute missing values)
# - NumberOfTrips has a mean and median of apx 3 (use -1 to impute missing values)
# - PitchSatisfactionScore has a mean and median of apx 3
# - NumberOfchildrenvisiting has a mean and median of apx 1 (use -1 to impute missing values)
# - MonthlyIncome has a mean of apx 23619 and median of 22347 (use mean to inpute missing values)
# -- There appear to be a number of outliers as high as 98678

# %%
vwu.describe(include='category').T
# Out:
#                count unique           top  freq
# ProdTaken       4888      2             0  3968
# TypeofContact   4863      2  Self Enquiry  3444
# Occupation      4888      4      Salaried  2368
# Gender          4888      3          Male  2916
# ProductPitched  4888      5         Basic  1842
# MaritalStatus   4888      4       Married  2340
# Passport        4888      2             0  3466
# OwnCar          4888      2             1  3032
# Designation     4888      5     Executive  1842

# %% [markdown]
# - ProdTaken is our target variable with not taken (0) being the most common ~ 77%
# - TypeofContact has 2 categories with Self Enquiry being the most common ~ 70% (use -1 to impute missing values)
# - Occupation has 3 categories with salaried being the most common
# - Gender has 3 categoires with Male being the most common (explore why there are 3 categories for Gender)
# - ProductPitched has 5 categories with Basic being the most common ~ 38%
# - MaritalStatus has 4 categories with Married being the most common (explore why there are 4 categories)
# - Passport has 2 categories with no passport (0) being the most common
# - OwnCar has 2 categories with yes (1) being the most common
# - Designation has 5 categories with Executive being them most common

# %% [markdown]
# #### Check number of unique values in each variable

# %%
vwu.nunique()
# Out:
# ProdTaken                      2
# Age                           44
# TypeofContact                  2
# CityTier                       3
# DurationOfPitch               34
# Occupation                     4
# Gender                         3
# NumberOfPersonVisiting         5
# NumberOfFollowups              6
# ProductPitched                 5
# PreferredPropertyStar          3
# MaritalStatus                  4
# NumberOfTrips                 12
# Passport                       2
# PitchSatisfactionScore         5
# OwnCar                         2
# NumberOfChildrenVisiting       4
# Designation                    5
# MonthlyIncome               2475
# dtype: int64

# %% [markdown]
# - Explore binning - Age, DurationOfPitch & Monthly Income

# %% [markdown]
# #### Explore Gender Categories

# %%
# Check Gender
genderU = vwu.Gender.unique()
print('Number of unique values in Gender: ', len(genderU))
vwu.Gender.value_counts()
# Out:
# Number of unique values in Gender:  3
# Male       2916
# Female     1817
# Fe Male     155
# Name: Gender, dtype: int64

# %% [markdown]
# - Gender has a category of Fe Male with 155 observations, we will assume this is a typo and change to Female

# %%
# Replace Fe Male with Female in Gender 
vwu['Gender'].loc[(vwu['Gender'] == 'Fe Male')] = 'Female'

# %%
# Check Gender
genderU = vwu.Gender.unique()
print('Number of unique values in Gender: ', len(genderU))
vwu.Gender.value_counts()
# Out:
# Number of unique values in Gender:  2
# Male       2916
# Female     1972
# Fe Male       0
# Name: Gender, dtype: int64

# %%
# Remove unused category Fe Male
vwu['Gender'].cat.remove_unused_categories(inplace=True)

# %%
# Check Gender
genderU = vwu.Gender.unique()
print('Number of unique values in Gender: ', len(genderU))
vwu.Gender.value_counts()
# Out:
# Number of unique values in Gender:  2
# Male      2916
# Female    1972
# Name: Gender, dtype: int64

# %% [markdown]
# #### Explore MaritalStatus categories

# %%
# Check MaritalStatus
msU = vwu.MaritalStatus.unique()
print('Number of unique values in MaritalStatus: ', len(msU))
vwu.MaritalStatus.value_counts()
# Out:
# Number of unique values in MaritalStatus:  4
# Married      2340
# Divorced      950
# Single        916
# Unmarried     682
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# - Unmarried accounts for the 4th category, we will leave this as is for the model

# %% [markdown]
# #### Explore DurationOfPitch to determine if there is a pattern for the missing values, then impute accordingly

# %%
#Look for other attributes around DurationOfPitch to determine how to impute
vwu.sort_values(by=['DurationOfPitch']).tail(25)
# Out:
#      ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 2387         1  34.0     Self Enquiry         1              NaN
# 2390         1  34.0  Company Invited         3              NaN
# 2393         1  34.0     Self Enquiry         3              NaN
# 2401         1  30.0  Company Invited         1              NaN
# 2409         1  32.0     Self Enquiry         1              NaN
# 2411         1  30.0  Company Invited         3              NaN
# 2419         1  39.0     Self Enquiry         3              NaN
# 2429         1  40.0     Self Enquiry         3              NaN
# 2431         1  35.0  Company Invited         1              NaN
# 2438         1  36.0     Self Enquiry         2              NaN
# 2621         1  20.0     Self Enquiry         1              NaN
# 2745         0  19.0     Self Enquiry         3              NaN
# 2957         1  21.0     Self Enquiry         1              NaN
# ...

# %% [markdown]
# - DurationOfPitch does not seem to have a pattern with the target variable or other variables, we will impute it with it's median due to deveral outliers

# %% [markdown]
# #### Reorder CityTier
# - CityTier has an order of 1 > 2 > 3, we want the 'best' tier to be a higher number for the model
# - New CityTier order will be 3 > 2 > 1

# %%
vwu.value_counts('CityTier')
# Out:
# CityTier
# 1    3190
# 3    1500
# 2     198
# dtype: int64

# %%
# Reorder CityTier 
replace_values = {1 : 3, 3 : 1 }                                                                                          
vwu = vwu.replace({"CityTier": replace_values})

# %%
vwu.value_counts('CityTier')
# Out:
# CityTier
# 3    3190
# 1    1500
# 2     198
# dtype: int64

# %% [markdown]
# #### Impute missing values
# Variable - impute value
# - Age - median
# - DurationOfPitch - median
# - NumberOfFollowups - median
# - PreferredPropertyStar - median
# - NumberOfTrips - median
# - NumberOfChildrenVisiting - median
# - MonthlyIncome - mean
# - TypeofContact - 'Self Enquiry'

# %%
# Impute missing values 
vwu['Age'].fillna(vwu['Age'].median(), inplace = True)
vwu['DurationOfPitch'].fillna(vwu['DurationOfPitch'].median(), inplace = True)
vwu['NumberOfFollowups'].fillna(vwu['NumberOfFollowups'].median(), inplace = True)
vwu['PreferredPropertyStar'].fillna(vwu['PreferredPropertyStar'].median(), inplace = True)
vwu['NumberOfChildrenVisiting'].fillna(vwu['NumberOfChildrenVisiting'].median(), inplace = True)
vwu['NumberOfTrips'].fillna(vwu['NumberOfTrips'].median(), inplace = True)
vwu['MonthlyIncome'].fillna(vwu['MonthlyIncome'].mean(), inplace = True)
vwu['TypeofContact'].fillna('Self Enquiry', inplace = True)


vwu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ProdTaken                 4888 non-null   category
#  1   Age                       4888 non-null   float64
#  2   TypeofContact             4888 non-null   category
#  3   CityTier                  4888 non-null   int64
#  4   DurationOfPitch           4888 non-null   float64
#  5   Occupation                4888 non-null   category
#  6   Gender                    4888 non-null   category
#  7   NumberOfPersonVisiting    4888 non-null   int64
#  8   NumberOfFollowups         4888 non-null   float64
#  9   ProductPitched            4888 non-null   category
#  10  PreferredPropertyStar     4888 non-null   float64
#  11  MaritalStatus             4888 non-null   category
#  12  NumberOfTrips             4888 non-null   float64
# ...

# %% [markdown]
# #### Convert floats to integers for plotting, ranking and binning

# %%
# Convert float variables to integer
vwu = vwu.astype({"Age":'int64', "DurationOfPitch":'int64', "NumberOfFollowups":'int64',
                  "PreferredPropertyStar":'int64', "NumberOfTrips":'int64', "NumberOfChildrenVisiting":'int64', 
                  "MonthlyIncome":'int64'})
vwu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ProdTaken                 4888 non-null   category
#  1   Age                       4888 non-null   int64
#  2   TypeofContact             4888 non-null   category
#  3   CityTier                  4888 non-null   int64
#  4   DurationOfPitch           4888 non-null   int64
#  5   Occupation                4888 non-null   category
#  6   Gender                    4888 non-null   category
#  7   NumberOfPersonVisiting    4888 non-null   int64
#  8   NumberOfFollowups         4888 non-null   int64
#  9   ProductPitched            4888 non-null   category
#  10  PreferredPropertyStar     4888 non-null   int64
#  11  MaritalStatus             4888 non-null   category
#  12  NumberOfTrips             4888 non-null   int64
# ...

# %% [markdown]
# # EDA & Additional Pre-Processing

# %%
# looking at value counts for non-numeric features

num_to_display = 35  
for colname in vwu.dtypes[vwu.dtypes == 'category'].index:
    val_counts = vwu[colname].value_counts(dropna=False)  # i want to see NA counts
    print(val_counts[:num_to_display])
    if len(val_counts) > num_to_display:
        print(f'Only displaying first {num_to_display} of {len(val_counts)} values.')
    print('\n') # just for more space between
# Out:
# 0    3968
# 1     920
# Name: ProdTaken, dtype: int64
#
#
# Self Enquiry       3469
# Company Invited    1419
# Name: TypeofContact, dtype: int64
#
#
# Salaried          2368
# Small Business    2084
# Large Business     434
# Free Lancer          2
# Name: Occupation, dtype: int64
#
#
# Male      2916
# Female    1972
# Name: Gender, dtype: int64
#
#
# Basic           1842
# Deluxe          1732
# Standard         742
# Super Deluxe     342
# King             230
# Name: ProductPitched, dtype: int64
#
#
# Married      2340
# Divorced      950
# Single        916
# Unmarried     682
# Name: MaritalStatus, dtype: int64
#
#
# 0    3466
# 1    1422
# Name: Passport, dtype: int64
#
#
# 1    3032
# 0    1856
# Name: OwnCar, dtype: int64
#
#
# Executive         1842
# Manager           1732
# Senior Manager     742
# AVP                342
# VP                 230
# Name: Designation, dtype: int64

# %% [markdown]
# #### ProdTaken value of 1 is about 18.8% of the data which matches the project brief.  The data is imbalanced, we will want to pay attention to the split.

# %%
# Function to create histogram and boxplot for numerical attributes
def histogram_boxplot(feature, figsize=(15,10), bins = None):
    """ Boxplot and histogram combined
    feature: 1-d feature array
    figsize: size of fig (default (9,8))
    bins: number of bins (default None / auto)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(nrows = 2,
                                           sharex = True,
                                           gridspec_kw = {"height_ratios": (.25, .75)}, 
                                           figsize = figsize 
                                           )
    sns.boxplot(feature, ax=ax_box2, showmeans=True, color='violet') 
    sns.distplot(feature, kde=F, ax=ax_hist2, bins=bins,palette="winter") if bins else sns.distplot(feature, kde=False, ax=ax_hist2) 
    ax_hist2.axvline(np.mean(feature), color='green', linestyle='--') 
    ax_hist2.axvline(np.median(feature), color='black', linestyle='-') 

# Function to create percentages for count plots - categorical attributes
def perc_on_bar(plot, feature):
    '''
    plot
    feature: categorical feature
    the function won't work if a column is passed in hue parameter
    '''
    total = len(feature) # length of the column
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total) 
        x = p.get_x() + p.get_width() / 2 - 0.05
        y = p.get_y() + p.get_height()           
        ax.annotate(percentage, (x, y), size = 12) 
    plt.show()

# %%
vwu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ProdTaken                 4888 non-null   category
#  1   Age                       4888 non-null   int64
#  2   TypeofContact             4888 non-null   category
#  3   CityTier                  4888 non-null   int64
#  4   DurationOfPitch           4888 non-null   int64
#  5   Occupation                4888 non-null   category
#  6   Gender                    4888 non-null   category
#  7   NumberOfPersonVisiting    4888 non-null   int64
#  8   NumberOfFollowups         4888 non-null   int64
#  9   ProductPitched            4888 non-null   category
#  10  PreferredPropertyStar     4888 non-null   int64
#  11  MaritalStatus             4888 non-null   category
#  12  NumberOfTrips             4888 non-null   int64
# ...

# %% [markdown]
# ## Uni-Variate Analysis

# %% [markdown]
# ### Age

# %%
# Age distribution
histogram_boxplot(vwu["Age"])

# %% [markdown]
# - Age shows a fairly uniform distribution with the bulk of age between ~ 25 and 48
# - There are no apparent outliers
# - Age could be binned as: LT30, 30-40, 40-50, GT50 if needed

# %% [markdown]
# ### CityTier

# %%
# plot ExpBin
plt.figure(figsize=(8,5))
ax = sns.countplot(vwu["CityTier"],palette='pastel')
perc_on_bar(ax,vwu["CityTier"])

# %% [markdown]
# - It is assumed that the CityTier refers to the City that the customer resides in
# - CityTier has been reordered to an order of 3 > 2 > 1
# - 65% of customers live in a higher tiered city and ~ 31% live in a lower tiered city
# - Surprisingly only 4% of customers live in a tier 2 city

# %% [markdown]
# ### DurationOfPitch

# %%
# DurationofPitch distribution
histogram_boxplot(vwu["DurationOfPitch"])

# %% [markdown]
# - DurationOfPitch is highly right skewed likely due to 2 very high outliers of ~ 127
# - We will impute these 2 outliers to the median

# %%
# Replace outliers higher than 60 to the median
vwu['DurationOfPitch'].loc[(vwu['DurationOfPitch'] > 60)] = vwu['DurationOfPitch'].median()

# %%
# DurationofPitch distribution
histogram_boxplot(vwu["DurationOfPitch"])

# %% [markdown]
# - Replacing the high outliers with the median as helped with the skew
# - The average amount of time for a pitch is ~ 15 with the majority of time below 17
# - DurationOfPitch could be binned as: LT10, 10-15, 16-25, GT25

# %% [markdown]
# ### NumberOfPersonVisiting

# %%
# DurationofPitch distribution
histogram_boxplot(vwu["NumberOfPersonVisiting"])

# %% [markdown]
# - Surprisingly there are no observations for customers taking a trip alone
# - The vast majority of observations are for customers traveling with > 2 additional persons with the majority being 3
# - Only a few of the observations have 1 additional traveler
# - This could imply that most  trips are with family and not alone or with significant other
# - We will want to check with MaritalStatus & ChildrenVisiting to see if additional patterns emerge

# %% [markdown]
# ### NumberOfFollowups

# %%
# NumberOfFollowups distribution
histogram_boxplot(vwu["NumberOfFollowups"])

# %% [markdown]
# - The majority of followups were 4 times with 3 times being ~ 600 less
# - It will be interesting to see how the number of followups impacted package purchases

# %% [markdown]
# ### PreferredPropertyStar

# %%
# PreferredPropertyStar distribution
histogram_boxplot(vwu["PreferredPropertyStar"])

# %% [markdown]
# - The majority of  customers prefer a property with 3 stars, with 4 and 5 starts be roughly equal

# %% [markdown]
# ### NumberOfTrips

# %%
# NumberOfTrips distribution
histogram_boxplot(vwu["NumberOfTrips"])

# %% [markdown]
# - The distribution of the number of trips is highly right skewed, likely due to very high outliers
# - It is possible that these outliers are due to business trips or something similar, we will want to check to see if these outliers have a pattern before deciding if they need to be imputed.
# - The majority of trips in a year are 2 & 3.

# %%
vwu.loc[vwu['NumberOfTrips'] > 10]
# Out:
#      ProdTaken  Age    TypeofContact  CityTier  DurationOfPitch  \
# 385          1   30  Company Invited         3               10
# 816          0   39  Company Invited         3               15
# 2829         1   31  Company Invited         3               11
# 3260         0   40  Company Invited         3               16
#
#           Occupation Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 385   Large Business   Male                       2                  3
# 816         Salaried   Male                       3                  3
# 2829  Large Business   Male                       3                  4
# 3260        Salaried   Male                       4                  4
#
#      ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 385           Basic                      3        Single             19
# 816          Deluxe                      4     Unmarried             21
# ...

# %% [markdown]
# - For the high outliers there are 2 - 4 other people accompanying the customer, they are single or unmarried with average monthly incomes and 3 of the 4 have children under 5 accompanying them.  It is still possible the majority of these trips are business related and the upcoming trip is with family.
# - We will leave these outliers in the model

# %% [markdown]
# ### PitchSatisfactionScore

# %%
# PitchSatisfactionScore distribution
histogram_boxplot(vwu["PitchSatisfactionScore"])

# %% [markdown]
# - A satisfaction score of 3 is the most common with 1, 4 & 5 being roughly equal
# - It will be interesting to see how satisfaction, followup and ProdTaken corelate

# %% [markdown]
# ### NumberOfChildrenVisiting

# %%
# NumberOfChildrenVisiting distribution
histogram_boxplot(vwu["NumberOfChildrenVisiting"])

# %% [markdown]
# - Most trips planned have 1 child under 5 with ~2200 observations
# - Trips with no children have ~ 1100 observations

# %% [markdown]
# ### MonthlyIncome

# %%
# MonthlyIncome distribution
histogram_boxplot(vwu["MonthlyIncome"])

# %% [markdown]
# - Monthly income has a few low and 2 very high outliers.  It is hard to know if these are relevant or not, we will need to examine them to determine if they need to be imputed

# %%
vwu.loc[vwu['MonthlyIncome'] < 15000]
# Out:
#      ProdTaken  Age TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 142          0   38  Self Enquiry         3                9  Large Business
# 2586         0   39  Self Enquiry         3               10  Large Business
#
#       Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# 142   Female                       2                  3         Deluxe
# 2586  Female                       3                  4         Deluxe
#
#       PreferredPropertyStar MaritalStatus  NumberOfTrips Passport  \
# 142                       3        Single              4        1
# 2586                      3        Single              5        1
#
#       PitchSatisfactionScore OwnCar  NumberOfChildrenVisiting Designation  \
# 142                        5      0                         0     Manager
# 2586                       5      0                         1     Manager
#
#       MonthlyIncome
# 142            1000
# 2586           4678

# %%
vwu.loc[vwu['MonthlyIncome'] > 40000]
# Out:
#      ProdTaken  Age TypeofContact  CityTier  DurationOfPitch Occupation  \
# 38           0   36  Self Enquiry         3               11   Salaried
# 2482         0   37  Self Enquiry         3               12   Salaried
#
#       Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# 38    Female                       2                  4          Basic
# 2482  Female                       3                  5          Basic
#
#       PreferredPropertyStar MaritalStatus  NumberOfTrips Passport  \
# 38                        3      Divorced              1        1
# 2482                      5      Divorced              2        1
#
#       PitchSatisfactionScore OwnCar  NumberOfChildrenVisiting Designation  \
# 38                         2      1                         0   Executive
# 2482                       2      1                         1   Executive
#
#       MonthlyIncome
# 38            95000
# 2482          98678

# %% [markdown]
# - 4 observations account for all outliers, 2 low and 2 high
# - None of the 4 outliers have purchased a package
# - The product pitched and the number of trips do not seem to match the income, however, the designation does.
# - The outliers seem to be out of place in some ways, but not in others.  These could be a typo or possibly an indication of a need to review guidelines for marketing on products pitched.
# - We will impute these 4 outliers to the median to get a more normalized distribution for customer profiling and modeling

# %%
# Replace MonthlyIncome outliers higher than 40000 to the median
vwu['MonthlyIncome'].loc[(vwu['MonthlyIncome'] > 40000)] = vwu['MonthlyIncome'].median()
# Replace MonthlyIncome outliers lower than 15000 to the median
vwu['MonthlyIncome'].loc[(vwu['MonthlyIncome'] < 15000)] = vwu['MonthlyIncome'].median()

# %%
# MonthlyIncome distribution
histogram_boxplot(vwu["MonthlyIncome"])

# %%
print(vwu["MonthlyIncome"].mean())
print(vwu["MonthlyIncome"].median())
# Out:
# 23597.56730769231
# 22655.0

# %% [markdown]
# - MonthlyIncome is still right skewed with the bulk being between ~ 17000 and 26000
# - Mean after adjusted outliers is 23597
# - There is a noticeable gap in income around 18000
# - MonthlyIncome could be binned as: LT20K, 20K-23K, 23K-26K, GT26K (This may change if obvious patterns emerge from multi-variate analysis)

# %%
vwu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ProdTaken                 4888 non-null   category
#  1   Age                       4888 non-null   int64
#  2   TypeofContact             4888 non-null   category
#  3   CityTier                  4888 non-null   int64
#  4   DurationOfPitch           4888 non-null   int64
#  5   Occupation                4888 non-null   category
#  6   Gender                    4888 non-null   category
#  7   NumberOfPersonVisiting    4888 non-null   int64
#  8   NumberOfFollowups         4888 non-null   int64
#  9   ProductPitched            4888 non-null   category
#  10  PreferredPropertyStar     4888 non-null   int64
#  11  MaritalStatus             4888 non-null   category
#  12  NumberOfTrips             4888 non-null   int64
# ...

# %% [markdown]
# ### ProdTaken

# %%
# plot ProdTaken
plt.figure(figsize=(8,5))
ax = sns.countplot(vwu["ProdTaken"],palette='pastel')
perc_on_bar(ax,vwu["ProdTaken"])

# %% [markdown]
# - As indicated in the product brief 18.8% of customers purchased a package

# %% [markdown]
# ### TypeofContact

# %%
# plot TypeofContact
plt.figure(figsize=(8,5))
ax = sns.countplot(vwu["TypeofContact"],palette='pastel')
perc_on_bar(ax,vwu["TypeofContact"])

# %% [markdown]
# - Self Enquiry is the majority of type of contact with 71%
# - This seems to indicate that 'passive' marketing is enticing more customers to enquire about packages, it will be interesting to see how type of contact correlates to product purchases
# - TypeOfContact will be encoded as 0:Company Invited, 1:Self Enquiry

# %% [markdown]
# ### Occupation

# %%
# plot Occupation
plt.figure(figsize=(8,5))
ax = sns.countplot(vwu["Occupation"],palette='pastel')
perc_on_bar(ax,vwu["Occupation"])

# %% [markdown]
# - The majority of occupations are Salaried (48%) and Small Business (42%)
# - We will want to see how Occupation, ProdTaken and MonthlySalary correlate
# - It is hard to know for sure how to 'rank' these for modeling, check for patterns with other variables before deciding how to encode (it would be good to consult an SME on this)

# %% [markdown]
# ### Gender

# %%
# plot Gender
plt.figure(figsize=(8,5))
ax = sns.countplot(vwu["Gender"],palette='pastel')
perc_on_bar(ax,vwu["Gender"])

# %% [markdown]
# - Males account for most of the observations at ~ 60%
# - Gender will be encoded as: 0:Female, 1:Male

# %% [markdown]
# ### ProductPitched

# %%
# plot ProductPitched
plt.figure(figsize=(8,5))
ax = sns.countplot(vwu["ProductPitched"],palette='pastel')
perc_on_bar(ax,vwu["ProductPitched"])

# %% [markdown]
# - Basic and Deluxe are the most common products pitched.
# - Basic accounts for ~ 40% and Deluxe ~35%
# - The highest package King only accounts for ~ 5% of observations
# - Ranking for products for models: 1:Basic, 2:Standard, 3:Deluxe, 4:Super Deluxe, 5:King

# %% [markdown]
# ### MaritalStatus

# %%
# plot MaritalStatus
plt.figure(figsize=(8,5))
ax = sns.countplot(vwu["MaritalStatus"],palette='pastel')
perc_on_bar(ax,vwu["MaritalStatus"])

# %% [markdown]
# - Married accounts for ~ 48% of all observations
# - Divorced, single & Unmarried are roughly equal around 18%
# - MaritalStatus will be One Hot Encoded for modeling

# %% [markdown]
# ### Passport

# %%
# plot Passport
plt.figure(figsize=(8,5))
ax = sns.countplot(vwu["Passport"],palette='pastel')
perc_on_bar(ax,vwu["Passport"])

# %% [markdown]
# - ~ 71% of customers do not have passports
# - It will be interesting to see how passport holders differ on number of trips and products

# %% [markdown]
# ### OwnCar

# %%
# plot OwnCar
plt.figure(figsize=(8,5))
ax = sns.countplot(vwu["OwnCar"],palette='pastel')
perc_on_bar(ax,vwu["OwnCar"])

# %% [markdown]
# - ~62% of customers own cars

# %% [markdown]
# ### Designation

# %%
# plot Designation
plt.figure(figsize=(8,5))
ax = sns.countplot(vwu["Designation"],palette='pastel')
perc_on_bar(ax,vwu["Designation"])

# %% [markdown]
# - Most customers are either an Executive (~ 38%) or Manager (~ 35%)
# - VP and AVP make up ~ 12% of customers
# - Designation will be encoded & ranked as: 1:Manager, 2:Senior Manager, 3:Executive, 4:AVP, 5:VP (it would be good to consult an SME to verify this)

# %% [markdown]
# #### Change appropriate variables to numeric and rank, Change target variable ProdTaken to integer
# #### We want to do this for the models but doing it now will allow us to see any correlations and patterns during Multi-Variate analysis
# #### MarritalStatus will be One Hot Encoded prior to modeling

# %%
# Rank order Designation 
Dreplace_values = {'Manager':1, 'Senior Manager':2, 'Executive':3, 'AVP':4, 'VP':5 }                                                                                          
vwu = vwu.replace({"Designation": Dreplace_values}) 

# Rank order ProductPitched 
Preplace_values = {'Basic':1, 'Standard':2, 'Deluxe':3, 'Super Deluxe':4, 'King':5 }                                                                                          
vwu = vwu.replace({"ProductPitched": Preplace_values}) 

# Rank order Gender
Greplace_values = {'Female':0, 'Male':1}                                                                                          
vwu = vwu.replace({"Gender": Greplace_values}) 

# Rank order Occupation
Oreplace_values = {'Free Lancer':1, 'Salaried':2, 'Small Business':3, 'Large Business':4}                                                                                          
vwu = vwu.replace({"Occupation": Oreplace_values}) 


# Rank order TypeofContact
Creplace_values = {'Company Invited':0, 'Self Enquiry':2}                                                                                          
vwu = vwu.replace({"TypeofContact": Creplace_values}) 

# Rank order MaritalStatus
Mreplace_values = {'Unmarried':1, 'Single':2, 'Divorced':3, 'Married':4}                                                                                          
vwu = vwu.replace({"MaritalStatus": Mreplace_values}) 

vwu = vwu.astype({"ProdTaken":'int64', "Passport":'int64', "OwnCar":'int64'})

# %%
vwu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ProdTaken                 4888 non-null   int64
#  1   Age                       4888 non-null   int64
#  2   TypeofContact             4888 non-null   int64
#  3   CityTier                  4888 non-null   int64
#  4   DurationOfPitch           4888 non-null   int64
#  5   Occupation                4888 non-null   int64
#  6   Gender                    4888 non-null   int64
#  7   NumberOfPersonVisiting    4888 non-null   int64
#  8   NumberOfFollowups         4888 non-null   int64
#  9   ProductPitched            4888 non-null   int64
#  10  PreferredPropertyStar     4888 non-null   int64
#  11  MaritalStatus             4888 non-null   int64
#  12  NumberOfTrips             4888 non-null   int64
#  13  Passport                  4888 non-null   int64
# ...

# %% [markdown]
# ## Multi-Variate Analysis

# %%
sns.set(rc={'figure.figsize':(16,10)})
sns.heatmap(vwu.corr(),
            annot=True,
            linewidths=.5,
            center=0,
            cbar=False,
            cmap="YlGnBu")
plt.show()

# %% [markdown]
# - ProdTaken is mildly correlated with Passport
# - Interestingly ProdTaken is mildly negatively correlated with ProductPitched (we will want to examine this more closely)
# - MonthlyIncome and ProdPitched are moderately correlated
# - Monthly Income ad Age are moderately correlated, as would be expected
# - As would be expected Number of Children Visiting and Number of Person Visiting are moderately correlated
# - Interestingly, Number of People & Children Visiting and Number of Followups are mildly correlated

# %% [markdown]
# ### Explore ProdTaken & ProductPitched

# %%
## Function to plot stacked bar chart
def stacked_plot(x):
    sns.set(palette="nipy_spectral")
    tab1 = pd.crosstab(x, vwu["ProdTaken"], margins=True)
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(x, vwu["ProdTaken"], normalize="index")
    tab.plot(kind="bar", stacked=True, figsize=(10, 5))
    # plt.legend(loc='lower left', frameon=False)
    # plt.legend(loc="upper left", bbox_to_anchor=(0,1))
    plt.show()

# %% [markdown]
# #### ProdTaken and MonthlyIncome

# %%
# ProdTaken and MonthlyIncome
fig, ax =plt.subplots(1,2, figsize= (15,5))
sns.kdeplot(x='MonthlyIncome', hue='ProdTaken', fill=True, data=vwu, ax=ax[0])
sns.boxplot(x="ProdTaken", y="MonthlyIncome", data=vwu, ax=ax[1])
fig.show()

# %% [markdown]
# - The majority of product purchasers have a monthly income of between 17000 & 25000.
# - Interestingly there are few purchases above monthly income of 30000

# %% [markdown]
# #### ProdTaken,  ProductPitched & Monthly Income

# %%
# MonthlyIncome and ProductPitched
fig, ax =plt.subplots(1,2, figsize= (15,5))
sns.kdeplot(x='MonthlyIncome', hue='ProductPitched', fill=True, palette='bright', data=vwu, ax=ax[0])
sns.boxplot(x="ProductPitched", y="MonthlyIncome", palette='bright', data=vwu, ax=ax[1])
fig.show()

# %% [markdown]
# - With few exceptions those who were pitched the top 2 packages had the highest incomes > 32000
# - Packages 1,2,3 were primarily pitched to customers with low to mid incomes of 17000 - 28000, however there were pitches to most incomes
# - Package 2 was more often pitched to mid level incomes than package 3

# %%
# ProdTaken and ProductPitched
stacked_plot(vwu["ProductPitched"])
# Out:
# ProdTaken          0    1   All
# ProductPitched
# 1               1290  552  1842
# 2                618  124   742
# 3               1528  204  1732
# 4                322   20   342
# 5                210   20   230
# All             3968  920  4888
# ------------------------------------------------------------------------------------------------------------------------

# %%
# MonthlyIncome, ProductPitched, ProdTaken
fig, ax =plt.subplots(1,2, figsize= (15,5))
sns.kdeplot(x='ProductPitched', hue='ProdTaken', fill=True, palette='bright', data=vwu, ax=ax[0])
fig.show()

# %% [markdown]
# - The basic package has the highest pitch rate with Deluxe a close second.
# - The basic package has the highest purchase rate overall with ~ 30% of customers purchasing
# - The Deluxe package has about 12% customers purchasing
# - The Standard package has about 16% purchase rate with a less than half of the pitches of either basic or deluxe.
# - RECOMMENDATION - Determine why the Standard package is not pitched more often as it has a higher purchase rate than the Deluxe package which is pitched more than 2x as often

# %% [markdown]
# #### ProdTaken, TypeofContact, PitchSatisfactionScore, NumberOfFollowups

# %%
cols = vwu[['DurationOfPitch', 'NumberOfFollowups', 'PitchSatisfactionScore']].columns.tolist()
plt.figure(figsize=(12,5))

for i, variable in enumerate(cols):
                     plt.subplot(1,3,i+1)
                     sns.boxplot(vwu['ProdTaken'],vwu[variable],palette="bright")
                     plt.tight_layout()
                     plt.title(variable)
plt.show()

# %%
# ProdTaken and ProductPitched
stacked_plot(vwu["DurationOfPitch"])
# Out:
# ProdTaken           0    1   All
# DurationOfPitch
# 5                   6    0     6
# 6                 268   39   307
# 7                 294   48   342
# 8                 273   60   333
# 9                 404   79   483
# 10                199   45   244
# 11                168   37   205
# 12                162   33   195
# 13                399   77   476
# 14                212   41   253
# 15                217   52   269
# 16                218   56   274
# 17                148   24   172
# 18                 56   19    75
# 19                 36   21    57
# 20                 46   19    65
# 21                 57   16    73
# 22                 66   23    89
# 23                 58   21    79
# 24                 54   16    70
# 25                 59   14    73
# 26                 60   12    72
# 27                 58   14    72
# 28                 44   17    61
# 29                 53   21    74
# 30                 65   30    95
# 31                 52   31    83
# ...

# %% [markdown]
# - Duration of pitch has the most successes at 19 and 31 at about 37% purchase rate
# - 5 minutes had no successes, but only 6 observations

# %%
# ProdTaken and ProductPitched
stacked_plot(vwu["PitchSatisfactionScore"])
# Out:
# ProdTaken                  0    1   All
# PitchSatisfactionScore
# 1                        798  144   942
# 2                        498   88   586
# 3                       1162  316  1478
# 4                        750  162   912
# 5                        760  210   970
# All                     3968  920  4888
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Most customers had a 3 satisfaction
# - Both 3 & 5 Satisfaction have a purchase rate of ~ 21%
# - All other satisfaction scores have about a 16% purchase rate

# %%
# ProdTaken and ProductPitched
stacked_plot(vwu["NumberOfFollowups"])
# Out:
# ProdTaken             0    1   All
# NumberOfFollowups
# 1                   156   20   176
# 2                   205   24   229
# 3                  1222  244  1466
# 4                  1726  387  2113
# 5                   577  191   768
# 6                    82   54   136
# All                3968  920  4888
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - The more followups there were the higher the purchase rate with 6 being ~40%
# - 4 followups was the most common with a purchase rate of about 18%

# %%
# ProdTaken and TypeofContact
stacked_plot(vwu["TypeofContact"])
# Out:
# ProdTaken         0    1   All
# TypeofContact
# 0              1109  310  1419
# 2              2859  610  3469
# All            3968  920  4888
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Company Invited has a 21% product acceptance rate
# - Self Enquiry has a 17% product acceptance rate, only 4% lower than company invited, but accounts for 70% of observations

# %% [markdown]
# #### Gender & ProdTaken

# %%
# ProdTaken and Gender
stacked_plot(vwu["Gender"])
# Out:
# ProdTaken     0    1   All
# Gender
# 0          1630  342  1972
# 1          2338  578  2916
# All        3968  920  4888
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - ~3% more males purchased product than females

# %%
# Number of Trips and ProductTaken
fig, ax =plt.subplots(1,2, figsize= (15,5))
sns.kdeplot(x='NumberOfTrips', hue='ProdTaken', fill=True, palette='bright', data=vwu, ax=ax[0])
sns.boxplot(x="ProdTaken", y="NumberOfTrips", palette='bright', data=vwu, ax=ax[1])
fig.show()

# %%
# ProdTaken and Gender
stacked_plot(vwu["NumberOfTrips"])
# Out:
# ProdTaken         0    1   All
# NumberOfTrips
# 1               508  112   620
# 2              1165  299  1464
# 3               990  229  1219
# 4               417   61   478
# 5               396   62   458
# 6               258   64   322
# 7               156   62   218
# 8                76   29   105
# 19                0    1     1
# 20                0    1     1
# 21                1    0     1
# 22                1    0     1
# All            3968  920  4888
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Most customers take 2 or 3 trips throughout the year and have about a 19% purchase rate
# - Customers who travel more, 7 or 8 times, are more likely to purchase with ~ 27% purchase rate

# %%
cols = vwu[['NumberOfPersonVisiting', 'NumberOfChildrenVisiting', 'Age']].columns.tolist()
plt.figure(figsize=(12,5))

for i, variable in enumerate(cols):
                     plt.subplot(1,3,i+1)
                     sns.boxplot(vwu['ProdTaken'],vwu[variable],palette="bright")
                     plt.tight_layout()
                     plt.title(variable)
plt.show()

# %% [markdown]
# - Customers between the ages of 29 and 40 are more likely to purchase a product
# - Number of Persons or Children Visiting are equally likely to purchase as not

# %%
# ProdTaken and Gender
stacked_plot(vwu["Occupation"])
# Out:
# ProdTaken      0    1   All
# Occupation
# 1              0    2     2
# 2           1954  414  2368
# 3           1700  384  2084
# 4            314  120   434
# All         3968  920  4888
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Salaried and Small Business are roughly equal at 17% for purchasing and make up 91% of all observations
# - Large Business has a purchase rate of ~ 38%

# %%
# ProdTaken and Gender
stacked_plot(vwu["Designation"])
# Out:
# ProdTaken       0    1   All
# Designation
# 1            1528  204  1732
# 2             618  124   742
# 3            1290  552  1842
# 4             322   20   342
# 5             210   20   230
# All          3968  920  4888
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Those with a designation of Executive are the most likely to purchase at 29%
# - managers and Senior Managers are the next most likely at ~ 13%
# - AVP's & VP's are the least likely to purchase with ~ 6% purchase rate

# %% [markdown]
# ### Customer profiles by product
# Product Description
# 1. Basic
# 2. Standard
# 3. Deluxe
# 4. Super Deluxe
# 5. King

# %%
## Function to plot stacked bar chart for ProductPitched
def pp_stacked_plot(x):
    sns.set(palette="bright")
    tab1 = pd.crosstab(x, vwu["ProductPitched"], margins=True)
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(x, vwu["ProductPitched"], normalize="index")
    tab.plot(kind="bar", stacked=True, figsize=(10, 5))
    # plt.legend(loc='lower left', frameon=False)
    # plt.legend(loc="upper left", bbox_to_anchor=(0,1))
    plt.show()

# %%
# ProductPitched and Designation
pp_stacked_plot(vwu["Designation"])
# Out:
# ProductPitched     1    2     3    4    5   All
# Designation
# 1                  0    0  1732    0    0  1732
# 2                  0  742     0    0    0   742
# 3               1842    0     0    0    0  1842
# 4                  0    0     0  342    0   342
# 5                  0    0     0    0  230   230
# All             1842  742  1732  342  230  4888
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### ProductPitched maps perfectly to Designation, this was verified in the original data, however there was only a very slight negative correlation between the two.  This is confusing and should be further investigated.
# - The level package pitched does not seem to match the level of designation / income.
# - The mapping is:
# -- Manager - Deluxe
# -- Senior Manager - Standard
# -- Executive - Basic
# -- AVP - Super Deluxe
# -- VP - King
#
# - RECOMMENDATION - It is possible that this is a data collection error, if it is not then marketing guidelines need to be reviewed for how products are pitched.
# - NOTE - With product pitched being perfectly mapped to designation with has correlation to age, income, etc. it is hard to know how well product pitches would perform if distributed differently
# - We will drop Designation prior to modeling

# %%
# plot ProductPitched
plt.figure(figsize=(8,5))
ax = sns.countplot(vwu["ProductPitched"],palette='bright')
perc_on_bar(ax,vwu["ProductPitched"])

# %%
# MonthlyIncome and ProductPitched
fig, ax =plt.subplots(1,2, figsize= (15,5))
sns.kdeplot(x='MonthlyIncome', hue='ProductPitched', fill=True, palette='bright', data=vwu, ax=ax[0])
sns.boxplot(x="ProductPitched", y="MonthlyIncome", palette='bright', data=vwu, ax=ax[1])
fig.show()

# %% [markdown]
# Monthly income for customers for each Product Pitched
# - Basic is concentrated in lower income ~ 17k to 23k but has outliers throughout and has the customers at ~ 38%
# - Standard is concentrated around ~ 23k to 30k with a some outliers on both sides with 15% of customers
# - Deluxe is concentrated around ~ 18 to 26k with 35% of customers
# - Super Deluxe is concentrated around 30k to 36k with few lower outliers and 7% of customers
# - King is concentrated in higher incomes around 33k to 38k with very few lower outliers
# - With ProductPitched and Designation being perfectly correlated we are basically looking at how income is distributed across Designations.

# %%
plt.figure(figsize=(10,5))
sns.countplot(vwu["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
# ProductPitched and Age
pp_stacked_plot(vwu["Age"])
# Out:
# ProductPitched     1    2     3    4    5   All
# Age
# 18                14    0     0    0    0    14
# 19                31    1     0    0    0    32
# 20                37    1     0    0    0    38
# 21                40    0     1    0    0    41
# 22                43    0     3    0    0    46
# 23                41    0     5    0    0    46
# 24                46    0    10    0    0    56
# 25                43    0    31    0    0    74
# 26                61    1    44    0    0   106
# 27                83    9    45    0    1   138
# 28                91   12    43    0    1   147
# 29               109   16    52    1    0   178
# 30               105   26    67    1    0   199
# 31                83   32    87    1    0   203
# 32                72   27    97    1    0   197
# 33                75   22    88    4    0   189
# 34                83   27    96    5    0   211
# 35                88   50    98    1    0   237
# ...

# %%
# ProductPitched and Age
fig, ax =plt.subplots(1,2, figsize= (15,5))
sns.kdeplot(x='Age', hue='ProductPitched', fill=True, palette='bright', data=vwu, ax=ax[0])
sns.boxplot(x="ProductPitched", y="Age", palette='bright', data=vwu, ax=ax[1])
fig.show()

# %% [markdown]
# - The bulk of customers age are between 26 and 46 with 36 nearly doubling other ages
# - Basic was pitched to all ages but is concentrated < 38 and accounts for 38% of all pitches
# - Standard was pitched to ages > 27 but is concentrated between 30 to 50 and accounted for 15% of all pitches
# - Deluxe was pitched to nearly all ages but is concentrated between ages 25 to 42 and accounts for 35% of all pitches
# - SuperDeluxe was pitched to ages > 39 but is concentrated between 42 and 55 and accounts for 7% of all pitches
# - King was pitched to ages > 40 but has a concentration similar to SuperDeluxe between the ages of 42 and 55 and accounts for about 5% of all pitches
# - With ProductPitched and Designation being perfectly correlated we are basically looking at how age is distributed across Designations.

# %%
# MonthlyIncome, Age & ProductPitched
plt.figure(figsize=(15,5))
sns.scatterplot(x='MonthlyIncome', y='Age', hue='ProductPitched', palette='bright', data=vwu)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Age'>

# %% [markdown]
# - There is a distinct gap in income between ~ 17k and 19k
# - Standard was the package primarily pitched between ~ 26k to 31k,

# %%
# ProductPitched and CityTier
pp_stacked_plot(vwu["CityTier"])
# Out:
# ProductPitched     1    2     3    4    5   All
# CityTier
# 1                268  288   784  120   40  1500
# 2                108   18    40   10   22   198
# 3               1466  436   908  212  168  3190
# All             1842  742  1732  342  230  4888
# ------------------------------------------------------------------------------------------------------------------------

# %%
# MonthlyIncome, Age & CityTier
plt.figure(figsize=(15,5))
sns.scatterplot(x='MonthlyIncome', y='Age', hue='CityTier', palette='bright', data=vwu)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Age'>

# %% [markdown]
# - Most customers (65%) reside in tier 3 cities with very few residing in tier 2 cities (4%), as the vast majority of customers reside in tier 1 or tier 2 cities we will not include tier 2 in this part of the analysis
#
# - Basic performs better in tier 3 cities overall
# - Standard performs better in tier 1 cities overall
# - Deluxe performs far better in tier 1 cities overall
# - Super Deluxe performs slightly better in tier 1 cities overall
# - King performs better in tier 3 cities overall
#
# - The city tier that a customer resides in looks to be fairly evenly distributed across income and age.
# - CityTier is not likely to be a strong predictor for product purchase

# %%
# ProductPitched and Occupation
pp_stacked_plot(vwu["Occupation"])
# Out:
# ProductPitched     1    2     3    4    5   All
# Occupation
# 1                  2    0     0    0    0     2
# 2                924  338   818  174  114  2368
# 3                720  320   790  150  104  2084
# 4                196   84   124   18   12   434
# All             1842  742  1732  342  230  4888
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - There are only 2 observations for Free Lance (1)
# - products pitched look to be fairly evenly distributed across Occupations

# %%
# ProductPitched and MaritalStatus
pp_stacked_plot(vwu["MaritalStatus"])
# Out:
# ProductPitched     1    2     3    4    5   All
# MaritalStatus
# 1                183  170   323    6    0   682
# 2                511   50   221   82   52   916
# 3                332  142   336   88   52   950
# 4                816  380   852  166  126  2340
# All             1842  742  1732  342  230  4888
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - The majority of observations are for married customers (48%)
# - Packages seem to be evenly distributed across divorced and married
# - Basic is most popular among Single customers
# - Standard is most popular among Unmarried Customers
# - Deluxe is most popular among Unmarried customers but also the most popular among divorced and married customers
# - Super Deluxe is fairly equally popular among single, divorced and married customers
# - King is fairly equally popular with single, divorced & married customers
# - RECOMMENDATION - Unmarried customers account for ~ 13% of observations and prefer the mid to lower priced products, it would be good to better understand who makes up this group.

# %%
# ProductPitched and NUmberOfPersonVisiting
pp_stacked_plot(vwu["NumberOfPersonVisiting"])
# Out:
# ProductPitched             1    2     3    4    5   All
# NumberOfPersonVisiting
# 1                          9    7    17    6    0    39
# 2                        517  209   511  106   75  1418
# 3                        911  363   848  165  115  2402
# 4                        404  162   355   65   40  1026
# 5                          1    1     1    0    0     3
# All                     1842  742  1732  342  230  4888
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Number of persons visiting of 5 has only 3 observations and will not be considered for this part of the analysis
# - All products are equally pitched among number of persons visiting of 2, 3 & 4
# - King was not pitched to 1 person visiting
# - RECOMMENDATION - It is reasonable to assume that 1 additional visitor could be a significant other and anything greater than that is traveling with family.  Increase pitches to number of visitors 1 or customers with no children

# %%
# ProductPitched and NumberOfChildrenVisiting
pp_stacked_plot(vwu["NumberOfChildrenVisiting"])
# Out:
# ProductPitched               1    2     3    4    5   All
# NumberOfChildrenVisiting
# 0                          404  172   391   84   31  1082
# 1                          794  319   755  168  110  2146
# 2                          517  198   474   74   72  1335
# 3                          127   53   112   16   17   325
# All                       1842  742  1732  342  230  4888
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - NumberOfChildrenVisiting  are fairly equal across products pitched

# %%
# ProductPitched and Gender
pp_stacked_plot(vwu["Gender"])
# Out:
# ProductPitched     1    2     3    4    5   All
# Gender
# 0                680  326   724  160   82  1972
# 1               1162  416  1008  182  148  2916
# All             1842  742  1732  342  230  4888
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Products pitched are fairly equal to both male and female

# %%
# ProductPitched and OwnCar
pp_stacked_plot(vwu["OwnCar"])
# Out:
# ProductPitched     1    2     3    4    5   All
# OwnCar
# 0                758  258   674  102   64  1856
# 1               1084  484  1058  240  166  3032
# All             1842  742  1732  342  230  4888
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Products pitched are fairly equal to both car owned and not

# %%
# ProductPitched and Passport
pp_stacked_plot(vwu["Passport"])
# Out:
# ProductPitched     1    2     3    4    5   All
# Passport
# 0               1274  532  1252  238  170  3466
# 1                568  210   480  104   60  1422
# All             1842  742  1732  342  230  4888
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Products pitched are fairly equal to both has passport and not

# %% [markdown]
# ### Customer Profile by Product Pitched

# %% [markdown]
# #### Basic
# - Age: Pitched to all with a concentration < 25
# - MonthlyIncome: Concentration of pitches between 17k & 23k
# - MaritalStatus: Most popular with Single
# - CityTier: Most popular in Tier 3 cities
# - Gender, NumberOfPersonVisiting, NumberOfChildrenVisiting, Occupation, OwnCar & Passport are farily equal in distribution
#
# #### Standard
# - Age: Pitched to all > 27 with a concentration between 20 & 50
# - MonthlyIncome: Concentration of pitches between 23k & 30k
# - MaritalStatus: Most popular with Unmarried
# - CityTier: Most popular in Tier 1 cities
# - Gender, NumberOfPersonVisiting, NumberOfChildrenVisiting, Occupation, OwnCar & Passport are farily equal in distribution
#
# #### Deluxe
# - Age: Pitched to all with a concentration between 25 & 42
# - MonthlyIncome: Concentration of pitches between 18k & 26k
# - MaritalStatus: Most popular with Divorced & Married
# - CityTier: Most popular in Tier 1 cities
# - Gender, NumberOfPersonVisiting, NumberOfChildrenVisiting, Occupation, OwnCar & Passport are farily equal in distribution
#
# #### Super Deluxe
# - Age: Pitched to customer > 39 with a concentration between 42 & 55
# - MonthlyIncome: Concentration of pitches between 30k & 36K
# - MaritalStatus: Most popular with Single, Divorced & Married
# - CityTier: Most popular in Tier 1 cities
# - Gender, NumberOfPersonVisiting, NumberOfChildrenVisiting, Occupation, OwnCar & Passport are farily equal in distribution
#
# #### King
# - Age: Pitched to customer > 40 with a concentration between 42 & 55
# - MonthlyIncome: Concentration of pitches between 33k & 38k
# - MaritalStatus: Most popular with Single, Divorced & Married
# - CityTier: Most popular in Tier 3 cities
# - Gender, NumberOfPersonVisiting, NumberOfChildrenVisiting, Occupation, OwnCar & Passport are farily equal in distribution

# %% [markdown]
# ## EDA Takeaways & Recommendations

# %% [markdown]
# ### Key Ovservations
#
#
# #### ProductPitched maps perfectly to Designation, this was verified in the original data.
# #### It is possible that this is a data collection error, however with product pitched being perfectly mapped to designation which has correlation to age, income, etc. it is hard to know how well product pitches would perform if distributed differently
#
# - The level package pitched does not seem to match the level of designation / income.
# - The mapping is:
# -- Manager - Deluxe
# -- Senior Manager - Standard
# -- Executive - Basic
# -- AVP - Super Deluxe
# -- VP - King
#
#
# - ProdTaken has a 18.8% purchase rate which matches the product brief
# - The most products pitched were Basic (38%) and Deluxe (35%)
# - Most ages are between 25 - 48 with 36 being nearly double that of other ages
# - 65% of all customers reside in a Tier 3 (highest) city, surprisingly only 4% reside in a Tier 2 city
# - The average pitch time is 15 minutes with the majority being less than 17 minutes
# - Most contact types are Self Enquiry (71%)
# - No customers are planning trips on their own, it is possible this is due to a typo in the data description where NumberOfPersonsVisiting is not in addition to the customer but total persons traveling
# - The vast majority of planned trips have > 2 additional persons which likely indicates traveling with family
# - Majority of trips per year is 2 & 3
# - Package 2 was more often pitched to mid level incomes than package 3
# - The basic package has the highest pitch rate with Deluxe a close second.
# - The basic package has the highest purchase rate overall with ~ 30% of customers purchasing
# - The Deluxe package has about 12% customers purchasing
# - The Standard package has about 16% purchase rate with a less than half of the pitches of either basic or deluxe.
# - Most customers (65%) reside in tier 3 cities with very few residing in tier 2 cities (4%)
# - Duration of pitch has the most successes at 19 and 31 at about 37% purchase rate
# - Most customers had a 3 satisfaction
# - Both 3 & 5 Satisfaction have a purchase rate of ~ 21%
# - All other satisfaction scores have about a 16% purchase rate
# - Most customers take 2 or 3 trips throughout the year and have about a 19% purchase rate
# - Customers who travel more, 7 or 8 times, are more likely to purchase with ~ 27% purchase rate
# - Customers between the ages of 29 and 40 are more likely to purchase a product
# - Number of Persons or Children Visiting are equally likely to purchase as not
# - Salaried and Small Business are roughly equal at 17% for purchasing and make up 91% of all observations
# - Self Enquiry has a 17% product purchase rate, only 4% lower than company invited, but accounts for 70% of observations
#
#
# ### Recommendations for next campaign
#
# - Closely review marketing guidelines for which products are pitched to specific customers.  Product choice by Designation alone is unlikely the best method.
#
# - Unmarried customers account for ~ 13% of observations and prefer the mid to lower priced products, it would be good to better understand who makes up this group.
#
# - Determine why the Standard package is not pitched more often as it has a higher purchase rate than the Deluxe package which is pitched more than 2x as often
#
# - Self Enquiry has a 17% product purchase rate, only 4% lower than company invited, but accounts for 70% of observations.  Determine if cost of outreach is worth the additional 4% purchase rate and if putting those dollars to better targeted (predicted) marketing would make more sense.
#
# - Increase marketing of Standard and Deluxe packages to single customers
#
#
# - Try and include additional data such as reason for trip, destination (in country, out of country, distance from home), better details on what drives the satisfaction score, how purchases are made (online, etc)
#
# - ProdTaken and ProductPitched have a mild negative correlation (-0.22), this should be further investigated

# %% [markdown]
# ### Prepare data for Split and model building

# %%
# Copy currently DataFrame
vwu1 = vwu.copy()

# %%
# Drop Designation as it perfectly maps to ProductPitched
vwu1.drop(columns=['Designation'], inplace=True)

# %%
vwu1.head(2)
# Out:
#    ProdTaken  Age  TypeofContact  CityTier  DurationOfPitch  Occupation  \
# 0          1   41              2         1                6           2
# 1          0   49              0         3               14           2
#
#    Gender  NumberOfPersonVisiting  NumberOfFollowups  ProductPitched  \
# 0       0                       3                  3               3
# 1       1                       3                  4               3
#
#    PreferredPropertyStar  MaritalStatus  NumberOfTrips  Passport  \
# 0                      3              2              1         1
# 1                      4              3              2         0
#
#    PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  MonthlyIncome
# 0                       2       1                         0          20993
# 1                       3       1                         2          20130

# %% [markdown]
# #### Split Data

# %%
X = vwu1.drop('ProdTaken', axis=1)
y = vwu1['ProdTaken']

# %%
# Splitting data into training and test set:
X_train, X_test, y_train, y_test =train_test_split(X, y, test_size=0.3, random_state=1,stratify=y)
print(X_train.shape, X_test.shape)
# Out:
# (3421, 17) (1467, 17)

# %% [markdown]
# #### Check ProdTaken distribution on test and train data

# %%
y.value_counts(1)
# Out:
# 0    0.811784
# 1    0.188216
# Name: ProdTaken, dtype: float64

# %%
y_test.value_counts(1)
# Out:
# 0    0.811861
# 1    0.188139
# Name: ProdTaken, dtype: float64

# %% [markdown]
# #### One Hot Encode MaritalStatus

# %%
# create dummy variable for train set
print('Before OHE:', X_train.shape)
X_train = pd.get_dummies(X_train, columns=['MaritalStatus'], drop_first=True)
print('After OHE:', X_train.shape)
display(X_train.head(2))

# create dummy variable for test set
print('Before OHE:', X_test.shape)
X_test = pd.get_dummies(X_test, columns=['MaritalStatus'], drop_first=True)
print('After OHE:', X_test.shape)
display(X_test.head(2))
# Out:
# Before OHE: (3421, 17)
# After OHE: (3421, 19)
#       Age  TypeofContact  CityTier  DurationOfPitch  Occupation  Gender  \
# 3234   34              2         3               12           2       1
# 657    29              2         3               13           3       0
#
#       NumberOfPersonVisiting  NumberOfFollowups  ProductPitched  \
# 3234                       3                  5               2
# 657                        3                  4               1
#
#       PreferredPropertyStar  NumberOfTrips  Passport  PitchSatisfactionScore  \
# 3234                      3              6         0                       3
# 657                       3              7         0                       5
#
#       OwnCar  NumberOfChildrenVisiting  MonthlyIncome  MaritalStatus_2  \
# 3234       0                         1          25797                0
# 657        1                         0          17532                0
#
#       MaritalStatus_3  MaritalStatus_4
# ...

# %% [markdown]
# ### Model evaluation - Using F1 Score
#
# We will be using the F1 Score as the primary metric for this model, because we want to reduce False Negatives as much as possible to ensure we don't lose existing customers willing to purchase while predicting new customers to target with marketing / outreach. We also want to ensure that marketing / outreach (and associated costs) are targeted toward customers who are more likely to purchase the new package.

# %%
##  Function to calculate different metric scores of the model - Accuracy, Recall and Precision
def get_metrics_score(model,flag=True):
    '''
    model : classifier to predict values of X

    '''
    # defining an empty list to store train and test results
    score_list=[] 
    
    pred_train = model.predict(X_train)
    pred_test = model.predict(X_test)
    
    train_acc = model.score(X_train,y_train)
    test_acc = model.score(X_test,y_test)
    
    train_recall = metrics.recall_score(y_train,pred_train)
    test_recall = metrics.recall_score(y_test,pred_test)
    
    train_precision = metrics.precision_score(y_train,pred_train)
    test_precision = metrics.precision_score(y_test,pred_test)
    
    train_f1 = f1_score(y_train,pred_train)
    test_f1 = f1_score(y_test,pred_test)
    
    score_list.extend((train_acc,test_acc,train_recall,test_recall,train_precision,test_precision, train_f1, test_f1))
        
    # If the flag is set to True then only the following print statements will be dispayed. The default value is set to True.
    if flag == True: 
        print("Accuracy on training set : ",model.score(X_train,y_train))
        print("Accuracy on test set : ",model.score(X_test,y_test))
        print("Recall on training set : ",metrics.recall_score(y_train,pred_train))
        print("Recall on test set : ",metrics.recall_score(y_test,pred_test))
        print("Precision on training set : ",metrics.precision_score(y_train,pred_train))
        print("Precision on test set : ",metrics.precision_score(y_test,pred_test))
        print("F1-Score on training set : ",metrics.f1_score(y_train,pred_train))
        print("F1-Score on test set : ",metrics.f1_score(y_test,pred_test))
    
    return score_list # returning the list with train and test scores

# %%
## Function to create confusion matrix
def make_confusion_matrix(model,y_actual,labels=[1, 0]):
    '''
    model : classifier to predict values of X
    y_actual : ground truth  
    
    '''
    y_predict = model.predict(X_test)
    cm=metrics.confusion_matrix( y_actual, y_predict, labels=[0, 1])
    df_cm = pd.DataFrame(cm, index = [i for i in ["Actual - No","Actual - Yes"]],
                  columns = [i for i in ['Predicted - No','Predicted - Yes']])
    group_counts = ["{0:0.0f}".format(value) for value in
                cm.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                         cm.flatten()/np.sum(cm)]
    labels = [f"{v1}\n{v2}" for v1, v2 in
              zip(group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=labels,fmt='')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Decision Tree Classifier

# %%
dTree = DecisionTreeClassifier(criterion = 'gini', random_state=1)
dTree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
# Review metrics on train and test set
dtree_estimator_score=get_metrics_score(dTree)
# Out:
# Accuracy on training set :  1.0
# Accuracy on test set :  0.8793456032719836
# Recall on training set :  1.0
# Recall on test set :  0.6956521739130435
# Precision on training set :  1.0
# Precision on test set :  0.6736842105263158
# F1-Score on training set :  1.0
# F1-Score on test set :  0.6844919786096257

# %% [markdown]
# - The decision tree is clearly over fitting as would be expected for the initial training.  We will tune the model to see if we can get a better F1 result

# %% [markdown]
# #### Decision Tree Hyperparameter Tuning

# %%
# Choose the type of classifier. 
estimator = DecisionTreeClassifier(random_state=2021)

# Grid of parameters to choose from
parameters = {'max_depth': np.arange(1,10), 
              'min_samples_leaf': [1, 2, 5, 7, 10, 15, 20],
              'max_leaf_nodes' : [2, 3, 5, 10],
              'min_impurity_decrease': [0.001, 0.01, 0.1],
              'criterion': ['gini', 'entropy'],
              'splitter': ['best','random']
             }

# Type of scoring used to compare parameter combinations
acc_scorer = metrics.make_scorer(metrics.f1_score)

# Run the grid search
grid_obj = GridSearchCV(estimator, parameters, scoring=acc_scorer,cv=2)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
estimator = grid_obj.best_estimator_

# Fit the best algorithm to the data. 
estimator.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, max_leaf_nodes=5,
#                        min_impurity_decrease=0.01, random_state=2021)

# %%
# Review metrics on train and test set
dtree_tuned_score=get_metrics_score(estimator)
# Out:
# Accuracy on training set :  0.8213972522654195
# Accuracy on test set :  0.8411724608043627
# Recall on training set :  0.3416149068322981
# Recall on test set :  0.3695652173913043
# Precision on training set :  0.5405405405405406
# Precision on test set :  0.6335403726708074
# F1-Score on training set :  0.4186489058039962
# F1-Score on test set :  0.4668192219679634

# %% [markdown]
# - The tuned decision tree is performing about 22% worse than the initial decision tree but is not over fitting. We will try other models before deciding if we need to try and improve on the decision tree

# %% [markdown]
# ### Bagging Classifier

# %%
# Fit the Bagging Classified
bagging_estimator=BaggingClassifier(random_state=2021)
bagging_estimator.fit(X_train,y_train)
# Out:
# BaggingClassifier(random_state=2021)

# %%
# Review metrics on train and test set
bagging_estimator_score=get_metrics_score(bagging_estimator)
# Out:
# Accuracy on training set :  0.9947383805904706
# Accuracy on test set :  0.9161554192229039
# Recall on training set :  0.9720496894409938
# Recall on test set :  0.6413043478260869
# Precision on training set :  1.0
# Precision on test set :  0.8805970149253731
# F1-Score on training set :  0.9858267716535433
# F1-Score on test set :  0.7421383647798742

# %% [markdown]
# - The Bagging classifier is performing fairly well on F1 (28% better then Dtree) but is overfitting in general.  We will see if we can improve the model via Hyperparameter Tuning

# %% [markdown]
# #### Bagging Model - Hyperparameter Tuning

# %%
# Choose the type of classifier. 
bagging_estimator_tuned = BaggingClassifier(random_state=2021)

# Grid of parameters to choose from
## add from article
parameters = {'max_samples': [0.7,0.8,0.9,1], 
              'max_features': [0.7,0.8,0.9,1],
              'n_estimators' : [10,20,50,150],
             }

# Type of scoring used to compare parameter combinations
acc_scorer = metrics.make_scorer(metrics.f1_score)

# Run the grid search
grid_obj = GridSearchCV(bagging_estimator_tuned, parameters, scoring=acc_scorer,cv=2)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
bagging_estimator_tuned = grid_obj.best_estimator_

# Fit the best algorithm to the data.
bagging_estimator_tuned.fit(X_train, y_train)
# Out:
# BaggingClassifier(max_features=0.9, max_samples=0.9, n_estimators=150,
#                   random_state=2021)

# %%
# Review metrics on train and test set
bagging_estimator_tuned_score=get_metrics_score(bagging_estimator_tuned)
# Out:
# Accuracy on training set :  1.0
# Accuracy on test set :  0.9263803680981595
# Recall on training set :  1.0
# Recall on test set :  0.644927536231884
# Precision on training set :  1.0
# Precision on test set :  0.9468085106382979
# F1-Score on training set :  1.0
# F1-Score on test set :  0.7672413793103448

# %% [markdown]
# - Slight increase in F1 Score (~ 2%) over non-tuned bagging model, but is over fitting worse than the non tuned model.  We will try other models and revisit the bagging models if needed.

# %% [markdown]
# ### Random Forest Classifier

# %%
# Train the random forest classifier
rf_estimator=RandomForestClassifier(random_state=2021)
rf_estimator.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=2021)

# %%
# View metrics on train and test set
rf_estimator_score=get_metrics_score(rf_estimator)
# Out:
# Accuracy on training set :  1.0
# Accuracy on test set :  0.9079754601226994
# Recall on training set :  1.0
# Recall on test set :  0.5507246376811594
# Precision on training set :  1.0
# Precision on test set :  0.9325153374233128
# F1-Score on training set :  1.0
# F1-Score on test set :  0.6924829157175398

# %% [markdown]
# - Random Forest is not performing very well for F1 and is over fitting the training data.  We will tune the Hyperparameters to see if we can improve

# %% [markdown]
# #### Random Forest Hyperparameter Tuned

# %%
# Choose the type of classifier. 
rf_estimator_tuned = RandomForestClassifier(random_state=2021)

# Grid of parameters to choose from
parameters = {
    "n_estimators": [10, 50, 150, 250],
    "min_samples_leaf": [1,5,8,10],
    "max_features": [0.1, 0.3, 0.7, 0.9],
    "max_samples": [0.1, 0.5, 0.7, 0.9],
             }

# Type of scoring used to compare parameter combinations
acc_scorer = metrics.make_scorer(metrics.f1_score)

# Run the grid search
grid_obj = GridSearchCV(rf_estimator_tuned, parameters, scoring=acc_scorer,cv=2)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
rf_estimator_tuned = grid_obj.best_estimator_

# Fit the best algorithm to the data.
rf_estimator_tuned.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_features=0.9, max_samples=0.9, n_estimators=250,
#                        random_state=2021)

# %%
# View metrics on train and test set
rf_estimator_tuned_score=get_metrics_score(rf_estimator_tuned)
# Out:
# Accuracy on training set :  1.0
# Accuracy on test set :  0.9277436946148603
# Recall on training set :  1.0
# Recall on test set :  0.6630434782608695
# Precision on training set :  1.0
# Precision on test set :  0.9336734693877551
# F1-Score on training set :  1.0
# F1-Score on test set :  0.7754237288135593

# %% [markdown]
# - The tuned Random Forest improved on Test F1 by ~ 8%, however the model is still over fit (perfect fit to the training variable).  We will adjust the weights on the target variable.

# %% [markdown]
# #### Random Forest Hyperparameter Tuned & Weighted

# %%
# Choose the type of classifier. 
rf_estimator_tuned_weight = RandomForestClassifier(random_state=2021)

# Grid of parameters to choose from
parameters = {
    "class_weight": [{0: 0.2, 1: 0.8}],
    "n_estimators": [10, 50, 150, 250],
    "min_samples_leaf": [1,5,8,10],
    "max_features": [0.1, 0.3, 0.7, 0.9],
    "max_samples": [0.1, 0.5, 0.7, 0.9],
             }

# Type of scoring used to compare parameter combinations
acc_scorer = metrics.make_scorer(metrics.f1_score)

# Run the grid search
grid_obj = GridSearchCV(rf_estimator_tuned, parameters, scoring=acc_scorer,cv=2)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
rf_estimator_tuned_weight = grid_obj.best_estimator_

# Fit the best algorithm to the data.
rf_estimator_tuned_weight.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight={0: 0.2, 1: 0.8}, max_features=0.9,
#                        max_samples=0.9, min_samples_leaf=5, n_estimators=150,
#                        random_state=2021)

# %%
# View metrics on train and test set
rf_estimator_tuned_weight_score=get_metrics_score(rf_estimator_tuned_weight)
# Out:
# Accuracy on training set :  0.9698918444899153
# Accuracy on test set :  0.8991138377641446
# Recall on training set :  0.967391304347826
# Recall on test set :  0.6920289855072463
# Precision on training set :  0.8836879432624114
# Precision on test set :  0.7519685039370079
# F1-Score on training set :  0.9236471460340994
# F1-Score on test set :  0.7207547169811321

# %% [markdown]
# - The tuned and weighted Random Forest decreased in Test F1 by ~ 5%, however the model is more generalized and not as over fit as previous models have been.  We will need to try other models to see if we can find an improvement in the F1 Score

# %% [markdown]
# ### Adaboost Classifier

# %%
#Fitting the model
ab_classifier = AdaBoostClassifier(random_state=2021)
ab_classifier.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(random_state=2021)

# %%
# View metrics on train and test set
ab_classifier_score=get_metrics_score(ab_classifier)
# Out:
# Accuracy on training set :  0.8491669102601579
# Accuracy on test set :  0.847307430129516
# Recall on training set :  0.34006211180124224
# Recall on test set :  0.3333333333333333
# Precision on training set :  0.7064516129032258
# Precision on test set :  0.696969696969697
# F1-Score on training set :  0.4591194968553459
# F1-Score on test set :  0.45098039215686275

# %% [markdown]
# - Adaboost is performing very poorly, 5% less than chance, however the model is balanced / generalized.  We will need to tune the model and see if we can get better results.

# %% [markdown]
# #### Adaboost Hyperparameter Tuning - base estimator Decision Tree

# %%
# Choose the type of classifier. 
ab_tuned = AdaBoostClassifier(random_state=2021)

# Grid of parameters to choose from
parameters = {
    #Let's try different max_depth for base_estimator
    "base_estimator":[DecisionTreeClassifier(max_depth=1),DecisionTreeClassifier(max_depth=2),
                      DecisionTreeClassifier(max_depth=3)],
    "n_estimators": [10, 30, 50, 90, 110],
    "learning_rate":[0.1, 0.3, 0.5, 0.9,]
}

# Type of scoring used to compare parameter  combinations
scorer = metrics.make_scorer(metrics.f1_score)

# Run the grid search
grid_obj = GridSearchCV(ab_tuned, parameters, scoring=scorer,cv=2)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
ab_tuned = grid_obj.best_estimator_

# Fit the best algorithm to the data.
ab_tuned.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=3),
#                    learning_rate=0.5, n_estimators=110, random_state=2021)

# %%
# View metrics on train and test set
ab_tuned_score=get_metrics_score(ab_tuned)
# Out:
# Accuracy on training set :  0.9731072785735165
# Accuracy on test set :  0.8841172460804363
# Recall on training set :  0.8726708074534162
# Recall on test set :  0.572463768115942
# Precision on training set :  0.9825174825174825
# Precision on test set :  0.7523809523809524
# F1-Score on training set :  0.924342105263158
# F1-Score on test set :  0.6502057613168725

# %% [markdown]
# - Tuning the hyperparameters for Adaboost improved F1 Test performance by ~ 9%, however the model is still showing signs of being over fit.

# %% [markdown]
# ### Gradient Boosting

# %%
#Fitting the model
gb_classifier = GradientBoostingClassifier(random_state=2021)
gb_classifier.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(random_state=2021)

# %%
# View metrics on train and test set
gb_classifier_score=get_metrics_score(gb_classifier)
# Out:
# Accuracy on training set :  0.8824904998538439
# Accuracy on test set :  0.8677573278800272
# Recall on training set :  0.4518633540372671
# Recall on test set :  0.39492753623188404
# Precision on training set :  0.8558823529411764
# Precision on test set :  0.8014705882352942
# F1-Score on training set :  0.5914634146341463
# F1-Score on test set :  0.529126213592233

# %% [markdown]
# - Gradient Boosting is performing better than the initial Adaboost but still only slightly better than chance, however the model looks to be fairly generalized.  We will want to tune the Gradient Boosted model to see if we can get some improvement.

# %% [markdown]
# #### Gradient Boosting Hyperparameter Tuning

# %%
# Choose the type of classifier. 
gb_tuned = GradientBoostingClassifier(init=AdaBoostClassifier(random_state=2021),random_state=2021)

# Grid of parameters to choose from
parameters = {
    "n_estimators": [100,150,200,250],
    "subsample":[0.8,0.9,1],
    "max_features":[0.7,0.8,0.9,1]
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score)

# Run the grid search
grid_obj = GridSearchCV(gb_tuned, parameters, scoring=scorer,cv=2)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
gb_tuned = grid_obj.best_estimator_

# Fit the best algorithm to the data.
gb_tuned.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(init=AdaBoostClassifier(random_state=2021),
#                            max_features=0.7, n_estimators=250,
#                            random_state=2021, subsample=0.8)

# %%
# View metrics on train and test set
gb_tuned_score=get_metrics_score(gb_tuned)
# Out:
# Accuracy on training set :  0.9155217772581117
# Accuracy on test set :  0.8738922972051807
# Recall on training set :  0.59472049689441
# Recall on test set :  0.4420289855072464
# Precision on training set :  0.9318734793187348
# Precision on test set :  0.7973856209150327
# F1-Score on training set :  0.7260663507109005
# F1-Score on test set :  0.5687645687645688

# %% [markdown]
# - Gradient Boosting improved the F1 Test Score by about 4% but is over fit, we will try other models to see if we can improve

# %% [markdown]
# ### XGBoost Classifier

# %%
#Fitting the model
xgb_classifier = XGBClassifier(random_state=2021, eval_metric='logloss')
xgb_classifier.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='logloss',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, random_state=2021, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=1, subsample=1, tree_method='exact',
#               validate_parameters=1, verbosity=None)

# %%
# View metrics on train and test set
xgb_classifier_score=get_metrics_score(xgb_classifier)
# Out:
# Accuracy on training set :  0.9994153756211634
# Accuracy on test set :  0.9134287661895024
# Recall on training set :  0.9968944099378882
# Recall on test set :  0.6376811594202898
# Precision on training set :  1.0
# Precision on test set :  0.8669950738916257
# F1-Score on training set :  0.9984447900466563
# F1-Score on test set :  0.7348643006263048

# %% [markdown]
# - XGBoost is performing fairly well for F1 Score, however it is still over fitting.  We will try and tune the model.

# %% [markdown]
# #### XGBoost Hyperparameter Tuning

# %%
# Choose the type of classifier. 
xgb_tuned = XGBClassifier(random_state=2021, eval_metric='logloss')

# Grid of parameters to choose from
parameters = {
    "n_estimators": [10,30,50, 100],
    "scale_pos_weight":[1,2,5, 7],
    "subsample":[0.7,0.9,1],
    "learning_rate":[0.05, 0.1, 0.3, 0.5, 0.9],
    "colsample_bytree":[0.7,0.9,1],
    "colsample_bylevel":[0.5,0.7,1]
}

# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.f1_score)

# Run the grid search
grid_obj = GridSearchCV(xgb_tuned, parameters,scoring=scorer,cv=2)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
xgb_tuned = grid_obj.best_estimator_

# Fit the best algorithm to the data.
xgb_tuned.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=0.7,
#               colsample_bynode=1, colsample_bytree=0.7, eval_metric='logloss',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.3, max_delta_step=0,
#               max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, random_state=2021, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=7, subsample=1, tree_method='exact',
#               validate_parameters=1, verbosity=None)

# %%
# View metrics on train and test set
xgb_tuned_score=get_metrics_score(xgb_tuned)
# Out:
# Accuracy on training set :  0.997076878105817
# Accuracy on test set :  0.9195637355146558
# Recall on training set :  1.0
# Recall on test set :  0.782608695652174
# Precision on training set :  0.9847094801223242
# Precision on test set :  0.7883211678832117
# F1-Score on training set :  0.9922958397534669
# F1-Score on test set :  0.7854545454545455

# %% [markdown]
# - The tuned XGBoost improved by about 5% but is still over fit.  We will try a few Stacking Classifiers to see if we can get better results.

# %% [markdown]
# ### Stacking Classifier - XGM Tuned Final Estimator

# %%
estimators = [('Decision Tree',estimator), ('Gradient Boosting',gb_tuned), ('Random Forest',rf_estimator_tuned)]

final_estimator = xgb_tuned

# estimators = [('Decision Tree Tuned',estimator), ('XGBoosted Tuned',gb_tuned), ('Random Forest Tuned',rf_estimator_tuned)]

# final_estimator = gb_tuned

stacking_classifier= StackingClassifier(estimators=estimators,final_estimator=final_estimator)

stacking_classifier.fit(X_train,y_train)
# Out:
# StackingClassifier(estimators=[('Decision Tree',
#                                 DecisionTreeClassifier(criterion='entropy',
#                                                        max_depth=4,
#                                                        max_leaf_nodes=5,
#                                                        min_impurity_decrease=0.01,
#                                                        random_state=2021)),
#                                ('Gradient Boosting',
#                                 GradientBoostingClassifier(init=AdaBoostClassifier(random_state=2021),
#                                                            max_features=0.7,
#                                                            n_estimators=250,
#                                                            random_state=2021,
#                                                            subsample=0.8)),
#                                ('Random Forest',
# ...

# %%
# View metrics on train and test set
stacking_score=get_metrics_score(stacking_classifier)
# Out:
# Accuracy on training set :  0.9874305758550131
# Accuracy on test set :  0.8773006134969326
# Recall on training set :  1.0
# Recall on test set :  0.8260869565217391
# Precision on training set :  0.9374090247452693
# Precision on test set :  0.6333333333333333
# F1-Score on training set :  0.9676934635612322
# F1-Score on test set :  0.7169811320754716

# %% [markdown]
# - The initial stacking model is performing fairly well with 0.717 F1 Test Score and while still over fit, it is not as over fit as many of our other models.

# %% [markdown]
# ### Stacking Classifier - GBM Tuned Final Estimator

# %%
estimators2 = [('Decision Tree Tuned',estimator), ('XGBoosted Tuned',xgb_tuned), ('Random Forest Tuned',rf_estimator_tuned)]

final_estimator2 = gb_tuned

stacking_classifier2= StackingClassifier(estimators=estimators2,final_estimator=final_estimator2)

stacking_classifier2.fit(X_train,y_train)
# Out:
# StackingClassifier(estimators=[('Decision Tree Tuned',
#                                 DecisionTreeClassifier(criterion='entropy',
#                                                        max_depth=4,
#                                                        max_leaf_nodes=5,
#                                                        min_impurity_decrease=0.01,
#                                                        random_state=2021)),
#                                ('XGBoosted Tuned',
#                                 XGBClassifier(base_score=0.5, booster='gbtree',
#                                               colsample_bylevel=0.7,
#                                               colsample_bynode=1,
#                                               colsample_bytree=0.7,
#                                               eval_metric='logloss', gamma=0,
#                                               gpu_id=-1, importance_ty...
# ...

# %%
# View metrics on train and test set
stacking_score2=get_metrics_score(stacking_classifier2)
# Out:
# Accuracy on training set :  0.9964922537269805
# Accuracy on test set :  0.9175187457396047
# Recall on training set :  1.0
# Recall on test set :  0.7753623188405797
# Precision on training set :  0.9817073170731707
# Precision on test set :  0.7838827838827839
# F1-Score on training set :  0.9907692307692307
# F1-Score on test set :  0.7795992714025501

# %% [markdown]
# - This stacking model is showing about a 7% improvement over the previous model, however it is heavily over fitting.

# %% [markdown]
# ### Stacking Classifier -  Random Forest Tuned Final Estimator

# %%
estimators3 = [('Decision Tree',estimator), ('Gradient Boosting',gb_tuned), ('XGBoosted Tuned',xgb_tuned)]

final_estimator3 = rf_estimator_tuned

stacking_classifier3= StackingClassifier(estimators=estimators3,final_estimator=final_estimator3)

stacking_classifier3.fit(X_train,y_train)
# Out:
# StackingClassifier(estimators=[('Decision Tree',
#                                 DecisionTreeClassifier(criterion='entropy',
#                                                        max_depth=4,
#                                                        max_leaf_nodes=5,
#                                                        min_impurity_decrease=0.01,
#                                                        random_state=2021)),
#                                ('Gradient Boosting',
#                                 GradientBoostingClassifier(init=AdaBoostClassifier(random_state=2021),
#                                                            max_features=0.7,
#                                                            n_estimators=250,
#                                                            random_state=2021,
#                                                            subsample=0.8)),
#                                ('XGBoosted Tuned',
# ...

# %%
# View metrics on train and test set
stacking_score3=get_metrics_score(stacking_classifier3)
# Out:
# Accuracy on training set :  0.9964922537269805
# Accuracy on test set :  0.9066121336059987
# Recall on training set :  0.9984472049689441
# Recall on test set :  0.7355072463768116
# Precision on training set :  0.9831804281345565
# Precision on test set :  0.7602996254681648
# F1-Score on training set :  0.9907550077041601
# F1-Score on test set :  0.7476979742173112

# %% [markdown]
# - This stacking model is showing about a 7% reduction in F1 Test Score from the previous model, and is still heavily over fitting.

# %% [markdown]
# ### Model Comparison

# %%
# defining list of models
models = [dTree, estimator, bagging_estimator, bagging_estimator_tuned, 
          rf_estimator, rf_estimator_tuned, rf_estimator_tuned_weight, 
         ab_classifier, ab_tuned, gb_classifier, gb_tuned, xgb_classifier,
         xgb_tuned, stacking_classifier, stacking_classifier2, stacking_classifier3]

# defining empty lists to add train and test results
acc_train = []
acc_test = []
recall_train = []
recall_test = []
precision_train = []
precision_test = []
f1_train = [] 
f1_test = []

# looping through all the models to get the metrics score - Accuracy, Recall and Precision
for model in models:
    
    j = get_metrics_score(model,False)
    acc_train.append(j[0])
    acc_test.append(j[1])
    recall_train.append(j[2])
    recall_test.append(j[3])
    precision_train.append(j[4])
    precision_test.append(j[5])
    f1_train.append(j[6])
    f1_test.append(j[7])

# %% [markdown]
# ### Results for the 16 models that were fitted, models are sorted by the Test F1 Score

# %%
# Build a DataFrame to compare models
comparison_frame = pd.DataFrame({'Model':['Decision Tree', 'Decision Tree Tuned', 'Bagging Classifier', 
                                          'Bagging Classifier Tuned', 'Random Forest', 'Random Forest Tuned', 
                                         'Random Forest Tuned Weighted', 'Adaboost', 'Adaboost Tuned',
                                         'Gradient Boosting', 'Gradient Boosting Tuned', 'XGBoost', 
                                         'XGBoost Tuned', 'Stacking - XGM Tuned', 'Stacking - GBM Tuned', 
                                         'Stacking - Random Forest Tuned'], 
                                          'Train_Accuracy': acc_train,'Test_Accuracy': acc_test,
                                          'Train_Recall':recall_train,'Test_Recall':recall_test,
                                          'Train_Precision':precision_train,'Test_Precision':precision_test,
                                           'Train_F1-Score':f1_train, 'Test_F1-Score':f1_test}) 

#Sorting models in decreasing order of test recall
comparison_frame.sort_values(by='Test_F1-Score',ascending=False)
# Out:
#                              Model  Train_Accuracy  Test_Accuracy  \
# 12                   XGBoost Tuned        0.997077       0.919564
# 14            Stacking - GBM Tuned        0.996492       0.917519
# 5              Random Forest Tuned        1.000000       0.927744
# 3         Bagging Classifier Tuned        1.000000       0.926380
# 15  Stacking - Random Forest Tuned        0.996492       0.906612
# 2               Bagging Classifier        0.994738       0.916155
# 11                         XGBoost        0.999415       0.913429
# 6     Random Forest Tuned Weighted        0.969892       0.899114
# 13            Stacking - XGM Tuned        0.987431       0.877301
# 4                    Random Forest        1.000000       0.907975
# 0                    Decision Tree        1.000000       0.879346
# 8                   Adaboost Tuned        0.973107       0.884117
# 10         Gradient Boosting Tuned        0.915522       0.873892
# ...

# %% [markdown]
# **Model Performance Conslusion**
# - The XGBoost Tuned model performed the best on Test F1 Score (0.785) but is overfitting on the training data F1 score (0.992)
# - Nearly every model is overfitting on the training data.
# - Models that are not overfitting have a poor F1 Test Score
# -- Decision Tree Tuned
# -- Adaboost
# -- Gradient Boosting
# -- Gradient Boosting Tuned
# - We will choose the **Random Forest Tuned Weighted** model to move forward with, while it has an ~ 6% lower Test F1 score the model is more generalized and likely to perform better when additional data is introduced.
# -- Test F1 Score (0.720)
# -- Train F1 Score (0.923)

# %% [markdown]
# ### Feature Importance - Random Forest Tuned Weighted Model

# %% [markdown]
# #### Random Forest Tuned Importances

# %%
feature_names = X_train.columns
importances = rf_estimator_tuned.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(12,12))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='violet', align='center')
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# - **MonthlyIncome** is the most significant variable in the Random Forest Tuned Weighted model followed by Age, DurationOfPitch & ProductPitched

# %% [markdown]
# ### Insights and Recommendations
#
# - Without additional information on the Wellness Tourism Package, such as expense / benefits, it is difficult to determine which customers may opt for that package.  Once the new package is classified along with the Customer Profiles by Product it should be easier to predict who will purchase each product.
#
#
# - Additional data on customers lifestyles could help improve / create models to predict who will opt for the new Wellness Tourism Package.
#
#
# - Additional research on what type of individual is more likely to be interested in wellness and travel would also be advised.  Possibly introduce a 'Wellness Score' to existing data and re-train the models.
#
#
# - Monthly Income, Age & Duration of Pitch are showing as the most important features for the model in predicting who will purchase a product, EDA mostly agrees with this.
#
#
# - Product Pitched is also showing as an important feature and EDA supports this, however the Product Pitched maps perfectly to Designation and has some correlation with Income & Age.  Using Designation as the sole means of determining what product to pitch to a given customer is not likely a good practice as many other factors, outside the scope of this data, could impact someones designation.  A better practice could be to determine which product to pitch based on the newly developed Customer Profiles by Product.  This may also reduce the slight negative correlation that ProductPitched has with ProduTaken.
#
#
# - Unmarried customers account for ~ 13% of observations and prefer the mid to lower priced products, it would be good to better understand who makes up this group.
#
#
# - Determine why the Standard package is not pitched more often as it has a higher purchase rate than the Deluxe package which is pitched more than 2x as often.
#
#
# - Self Enquiry has a 17% product purchase rate, only 4% lower than company invited, but accounts for 70% of observations. Determine if the cost of outreach is worth the additional 4% purchase rate and if putting those dollars to better targeted  marketing (predicted purchasers) would make more sense.
#
#
# - Increase marketing of Standard and Deluxe packages to single customers.
#
#
# - Reworking the data & data dictionary to better indicate if NumberOfPersonsVisiting include the customer or is in addition.  No customers are showing to travel alone, which makes this suspect.
#
#
# - Collecting additional data on products pitched once new guidelines for how products are pitched are in place will likely increase the predictive power of these models.
#
#
# - Including additional data such as family size, reason for trip, destination (in country, out of country, distance from home), better details on what drives the satisfaction score, how purchases are made (online, etc), what drove a Self Enquiry, etc. could greatly increase the outcomes of future analysis and marketing plans.
